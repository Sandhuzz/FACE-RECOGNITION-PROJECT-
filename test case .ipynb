# %%
from keras.models import model_from_json
from keras.preprocessing.image import load_img
import numpy as np

# %%
# Load model
json_file = open("emotiondetector.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("emotiondetector.h5")

# %%
# Labels
label = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
# Feature extraction
def ef(image):
    img = load_img(image, color_mode='grayscale', target_size=(48, 48))
    feature = np.array(img)
    feature = feature.reshape(1, 48, 48, 1)
    return feature / 255.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = 'C:/Users/Asus/OneDrive/Documents/face recognition project/images/test/sad/580.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# model prediction is  sad

# %%
image = 'C:/Users/Asus/OneDrive/Documents/face recognition project/images/test/fear/414.jpg'
print("original image is of fear")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# model prediction is  fear

# %%
image = 'C:/Users/Asus/OneDrive/Documents/face recognition project/images/test/disgust/7068.jpg'
print("original image is of disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of disgust
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# model prediction is  disgust

# %%
image = 'C:/Users/Asus/OneDrive/Documents/face recognition project/images/test/surprise/5530.jpg'
print("original image is of surprise")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# model prediction is  surprise

# %%
image = 'C:/Users/Asus/OneDrive/Documents/face recognition project/images/test/happy/568.jpg'
print("original image is of happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# model prediction is  happy

# %%
image = 'C:/Users/Asus/OneDrive/Documents/face recognition project/images/test/angry/1071.jpg'
print("original image is of angry")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# model prediction is  angry

# %%
image = 'C:/Users/Asus/OneDrive/Documents/face recognition project/images/test/neutral/1669.jpg'
print("original image is of neutral")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# model prediction is  neutral
